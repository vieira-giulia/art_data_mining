# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set(style='whitegrid')

# %%
df = pd.read_csv('omniart-paintings-filtered.csv')
df.head()
# Out:
#             artwork_name   artist_full_name  creation_year  century  school  \
# 0                 70 amx            xynphix         2007.0     21.0  modern
# 1   crucifixion (detail)  andrea da firenze         1366.0     14.0  Italia
# 2                  faith    giuseppe angeli         1754.0     18.0  Italia
# 3              lamp post       williamsnape         2010.0     21.0  modern
# 4  the one that got away       katiehofgard         2009.0     21.0  modern
#
#                                        color_pallete dominant_color  \
# 0  [u'#e2f5e5', u'#a5ab9e', u'#65c7a3', u'#243b39...        #a5ab9e
# 1  [u'#a18b78', u'#866b58', u'#7c5340', u'#5b4b3f...        #110d0d
# 2  [u'#000202', u'#a3754c', u'#935531', u'#1d130c...        #000000
# 3  [u'#cdada2', u'#987d71', u'#503b33', u'#311d1b...        #233b49
# 4  [u'#ffffff', u'#fdfdfd', u'#fcfffe', u'#9d7957...        #ffffff
#
#                                        palette_count
# ...

# %%
print("General information:")
df.info()
# Out:
# General information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264247 entries, 0 to 264246
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   artwork_name      264245 non-null  object
#  1   artist_full_name  264247 non-null  object
#  2   creation_year     264247 non-null  float64
#  3   century           264247 non-null  float64
#  4   school            264243 non-null  object
#  5   color_pallete     264247 non-null  object
#  6   dominant_color    264247 non-null  object
#  7   palette_count     264247 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 16.1+ MB

# %%
print("\nDescriptive statistics for numerical columns:")
display(df.describe())
# Out:
# Descriptive statistics for numerical columns:
#        creation_year        century
# count  264247.000000  264247.000000
# mean     1927.266542      20.037310
# std       169.213789       1.820886
# min     -1000.000000      -9.000000
# 25%      1913.000000      20.000000
# 50%      2010.000000      21.000000
# 75%      2013.000000      21.000000
# max      2017.000000      21.000000

# %%
print("\nEmpty values per column:")
print(df.isna().sum())
# Out:
# Empty values per column:
# artwork_name        2
# artist_full_name    0
# creation_year       0
# century             0
# school              4
# color_pallete       0
# dominant_color      0
# palette_count       0
# dtype: int64

# %%
num_artists = df['artist_full_name'].nunique()
print(f"Number of unique artists: {num_artists}")
# Out:
# Number of unique artists: 59683

# %%
print("\nProportion of paintings per century:")
paintings_per_century = df['century'].value_counts(10).sort_index()
print(paintings_per_century)
# Out:
# Proportion of paintings per century:
# century
# -9.0     0.000004
# -2.0     0.000011
# -1.0     0.000015
#  1.0     0.000201
#  2.0     0.000015
#  3.0     0.000019
#  4.0     0.000015
#  5.0     0.000008
#  6.0     0.000049
#  7.0     0.000030
#  8.0     0.000083
#  9.0     0.000091
#  10.0    0.000132
#  11.0    0.000272
#  12.0    0.000870
#  13.0    0.001854
#  14.0    0.009612
#  15.0    0.029393
#  16.0    0.037575
#  17.0    0.047569
#  18.0    0.026207
#  19.0    0.079532
#  20.0    0.067304
#  21.0    0.699138
# Name: proportion, dtype: float64

# %%
print("\nProportion of paintings per school:")
top_schools = df['school'].value_counts(10)
print(top_schools)
# Out:
# Proportion of paintings per school:
# school
# modern            0.696961
# unknown           0.177042
# italian           0.041333
# dutch             0.014646
# french            0.014509
#                     ...
# franco-flemish    0.000004
# iran              0.000004
# mexican           0.000004
# bavaria,          0.000004
# sri               0.000004
# Name: proportion, Length: 80, dtype: float64

# %%
# Cell 8: Gráfico de barras - Top 15 cores dominantes
plt.figure(figsize=(10,6))

# Get the top 15 dominant colors
dominant_color_counts = df['dominant_color'].value_counts().head(100)

# Create the color list from the hex names (index of the Series)
color_palette = dominant_color_counts.index.tolist()

# Plot
sns.barplot(
    x=dominant_color_counts.values,
    y=dominant_color_counts.index,
    palette=color_palette
)

plt.title('Top 30 Dominant Colors')
plt.xlabel('Count')
plt.ylabel('Color (Hex Code)')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/gw/xlj0k3j514bcjc1zdr412my80000gn/T/ipykernel_45045/2822476796.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
df['school_wrapped'] = df['school'].apply(
    lambda x: '\n'.join([str(x)[i:i+30] for i in range(0, len(str(x)), 30)]) if pd.notna(x) else 'Unknown'
)

plt.figure(figsize=(30, 12))
ax = sns.stripplot(
    data=df,
    x='school_wrapped',
    y='century',
    jitter=True,
    alpha=0.6,
    palette='tab20',
)

plt.title('Paintings per Century and School')
plt.xlabel('Century')
plt.ylabel('Artistic School')
plt.xticks(rotation=90)
y_ticks = ax.get_yticks()
for y in y_ticks:
    ax.axhline(y=y, color='gray', linestyle='--', linewidth=0.7, alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/gw/xlj0k3j514bcjc1zdr412my80000gn/T/ipykernel_45045/3167737530.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(

# %%
df['school_wrapped'] = df['school'].apply(
    lambda x: '\n'.join([str(x)[i:i+30] for i in range(0, len(str(x)), 30)]) if pd.notna(x) else 'Unknown'
)

plt.figure(figsize=(30, 12))

# Violin plot to show distribution (density of data)
sns.violinplot(
    data=df,
    x='school_wrapped',
    y='century',
    palette='pastel',
    inner=None,  # No individual points inside
    linewidth=0,
    cut=0  # Don't extend violins beyond min/max
)

# Overlay stripplot to show individual points
sns.stripplot(
    data=df,
    x='school_wrapped',
    y='century',
    jitter=True,
    alpha=0.6,
    palette='tab20',
    size=3  # Control point size
)

plt.title('Paintings per Century and School')
plt.xlabel('Artistic School')
plt.ylabel('Century')
plt.xticks(rotation=90)

# Optional: horizontal lines at each y-tick
y_ticks = plt.gca().get_yticks()
for y in y_ticks:
    plt.axhline(y=y, color='gray', linestyle='--', linewidth=0.6, alpha=0.4)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/gw/xlj0k3j514bcjc1zdr412my80000gn/T/ipykernel_45045/3841337654.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# /var/folders/gw/xlj0k3j514bcjc1zdr412my80000gn/T/ipykernel_45045/3841337654.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(

# %%
import matplotlib.pyplot as plt
import numpy as np

# Take the top N paintings (or all, capped to a reasonable number)
N = 400  # for example, a 20x20 grid (adjust as you want)
colors = df['dominant_color'].head(N).tolist()

# Convert hex to RGB normalized
def hex_to_rgb(h):
    h = h.lstrip('#')
    return tuple(int(h[i:i+2], 16)/255 for i in (0, 2, 4))

rgb_colors = np.array([hex_to_rgb(c) for c in colors])

# Compute grid size (square as close as possible)
grid_size = int(np.ceil(np.sqrt(N)))

# Create an empty image array: (grid_size x grid_size x 3)
img = np.ones((grid_size, grid_size, 3))

# Fill the array with the RGB colors, row by row
for i, color in enumerate(rgb_colors):
    row = i // grid_size
    col = i % grid_size
    img[row, col, :] = color

# Count unique colors
unique_colors = len(set(colors))
print(f"Number of unique colors in top {N}: {unique_colors}")

# Plot with coordinates on axes
fig, ax = plt.subplots(figsize=(12, 12))
ax.imshow(img)
ax.set_xticks(np.arange(grid_size))
ax.set_yticks(np.arange(grid_size))

# Label ticks with coordinate numbers
ax.set_xticklabels(np.arange(grid_size))
ax.set_yticklabels(np.arange(grid_size))

# Minor ticks for grid lines
ax.set_xticks(np.arange(-0.5, grid_size, 1), minor=True)
ax.set_yticks(np.arange(-0.5, grid_size, 1), minor=True)
ax.grid(which='minor', color='gray', linestyle='-', linewidth=0.5)

plt.title(f'Color grid of top {N} paintings by dominant color')
plt.show()
# Out:
# Number of unique colors in top 400: 356
