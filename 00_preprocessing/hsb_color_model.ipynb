# %%
import sys
import os
sys.path.append(os.path.abspath("../"))

import utils
import pandas as pd
import ast

# %% [markdown]
# HSB (hue, saturation, and brightness) color transform: more intuitive color choice by artists. Created by Alvy Ray Smith in 1974.

# %%
df = pd.read_csv("omniart-paintings-filtered-clean.csv")

# %%
df
# Out:
#                                              artwork_name  \
# 0                                                  70 amx
# 1                                    crucifixion (detail)
# 2                                                   faith
# 3                                               lamp post
# 4                                   the one that got away
# ...                                                   ...
# 264242                                              truth
# 264243  yavanna queen of the earth giver of fruits-tif...
# 264244                                            unknown
# 264245                                            unknown
# 264246                            portrait of a gentleman
#
#               artist_full_name  creation_year  century   school  \
# 0                      xynphix         2007.0     21.0   modern
# 1            andrea da firenze         1366.0     14.0    Italy
# 2              giuseppe angeli         1754.0     18.0    Italy
# 3                 williamsnape         2010.0     21.0   modern
# 4                 katiehofgard         2009.0     21.0   modern
# ...                        ...            ...      ...      ...
# 264242            circlekeeper         2008.0     21.0   modern
# 264243    tiffany-illustration         2017.0     21.0   modern
# 264244           kano furunobu         1700.0     18.0    Japan
# 264245             wang yuanqi         1715.0     18.0    China
# 264246  louis-gabriel blanchet         1725.0     18.0   France
#
#                                             color_pallete dominant_color  \
# 0       [u'#e2f5e5', u'#a5ab9e', u'#65c7a3', u'#243b39...        #a5ab9e
# 1       [u'#a18b78', u'#866b58', u'#7c5340', u'#5b4b3f...        #110d0d
# 2       [u'#000202', u'#a3754c', u'#935531', u'#1d130c...        #000000
# 3       [u'#cdada2', u'#987d71', u'#503b33', u'#311d1b...        #233b49
# 4       [u'#ffffff', u'#fdfdfd', u'#fcfffe', u'#9d7957...        #ffffff
# ...                                                   ...            ...
# 264242  [u'#a86f61', u'#a09d79', u'#372b2e', u'#252125...        #252125
# 264243  [u'#ffffff', u'#feffff', u'#eef1df', u'#c0af95...        #ffffff
# 264244  [u'#b6ad97', u'#af9974', u'#a78d66', u'#a19371...        #7e4e48
# 264245  [u'#f8f3ed', u'#f4ede6', u'#f1e3d0', u'#edd9bb...        #e7d2b5
# 264246  [u'#a9977f', u'#39211a', u'#2d2b25', u'#251f1a...        #393227
#
#                                             palette_count
# 0       [4009, 7637, 3303, 6147, 4742, 3908, 7216, 514...
# 1       [6226, 6056, 4293, 6101, 5185, 5292, 6392, 384...
# 2       [1007, 4537, 4708, 4466, 4432, 2946, 4776, 448...
# 3       [4225, 4308, 4914, 6274, 6911, 6261, 6753, 421...
# 4       [43399, 1136, 407, 2637, 2812, 679, 3585, 2514...
# ...                                                   ...
# 264242  [1312, 5526, 9605, 9971, 4030, 5524, 5562, 286...
# 264243  [15056, 255, 5087, 6846, 9838, 1577, 4027, 476...
# 264244  [3431, 5740, 4247, 4971, 6362, 6885, 5328, 445...
# 264245  [6512, 6102, 860, 6846, 4826, 5036, 5117, 3297...
# 264246  [3673, 4253, 5392, 6641, 3191, 7046, 4680, 706...
#
# [264247 rows x 8 columns]

# %%
# Parse strings as lists
df['color_pallete'] = df['color_pallete'].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else x
)

# %%
# Apply and expand into new columns: get list of HEX colors saved in original omniart dataframe
top_n = 10
hsb = df['color_pallete'].apply(lambda lst: utils.extract_hsb_components_from_vec(lst, top_n=top_n))

# %%
# Split tuples into separate lists: each dimension has a vector of 10 colors
df[['H', 'S', 'B']] = pd.DataFrame(hsb.tolist(), index=df.index)

# %%
df
# Out:
#                                              artwork_name  \
# 0                                                  70 amx
# 1                                    crucifixion (detail)
# 2                                                   faith
# 3                                               lamp post
# 4                                   the one that got away
# ...                                                   ...
# 264242                                              truth
# 264243  yavanna queen of the earth giver of fruits-tif...
# 264244                                            unknown
# 264245                                            unknown
# 264246                            portrait of a gentleman
#
#               artist_full_name  creation_year  century   school  \
# 0                      xynphix         2007.0     21.0   modern
# 1            andrea da firenze         1366.0     14.0    Italy
# 2              giuseppe angeli         1754.0     18.0    Italy
# 3                 williamsnape         2010.0     21.0   modern
# 4                 katiehofgard         2009.0     21.0   modern
# ...                        ...            ...      ...      ...
# 264242            circlekeeper         2008.0     21.0   modern
# 264243    tiffany-illustration         2017.0     21.0   modern
# 264244           kano furunobu         1700.0     18.0    Japan
# 264245             wang yuanqi         1715.0     18.0    China
# 264246  louis-gabriel blanchet         1725.0     18.0   France
#
#                                             color_pallete dominant_color  \
# 0       [#e2f5e5, #a5ab9e, #65c7a3, #243b39, #aee2cb, ...        #a5ab9e
# 1       [#a18b78, #866b58, #7c5340, #5b4b3f, #352f28, ...        #110d0d
# 2       [#000202, #a3754c, #935531, #1d130c, #cfd0a0, ...        #000000
# 3       [#cdada2, #987d71, #503b33, #311d1b, #233b49, ...        #233b49
# 4       [#ffffff, #fdfdfd, #fcfffe, #9d7957, #9a5f35, ...        #ffffff
# ...                                                   ...            ...
# 264242  [#a86f61, #a09d79, #372b2e, #252125, #242d42, ...        #252125
# 264243  [#ffffff, #feffff, #eef1df, #c0af95, #896962, ...        #ffffff
# 264244  [#b6ad97, #af9974, #a78d66, #a19371, #a08d67, ...        #7e4e48
# 264245  [#f8f3ed, #f4ede6, #f1e3d0, #edd9bb, #fbf8f2, ...        #e7d2b5
# 264246  [#a9977f, #39211a, #2d2b25, #251f1a, #1c1d1d, ...        #393227
#
#                                             palette_count  \
# 0       [4009, 7637, 3303, 6147, 4742, 3908, 7216, 514...
# 1       [6226, 6056, 4293, 6101, 5185, 5292, 6392, 384...
# 2       [1007, 4537, 4708, 4466, 4432, 2946, 4776, 448...
# 3       [4225, 4308, 4914, 6274, 6911, 6261, 6753, 421...
# 4       [43399, 1136, 407, 2637, 2812, 679, 3585, 2514...
# ...                                                   ...
# 264242  [1312, 5526, 9605, 9971, 4030, 5524, 5562, 286...
# 264243  [15056, 255, 5087, 6846, 9838, 1577, 4027, 476...
# 264244  [3431, 5740, 4247, 4971, 6362, 6885, 5328, 445...
# 264245  [6512, 6102, 860, 6846, 4826, 5036, 5117, 3297...
# 264246  [3673, 4253, 5392, 6641, 3191, 7046, 4680, 706...
#
#                                                         H  \
# 0       [0.3596491228070177, 0.2435897435897434, 0.438...
# 1       [0.07723577235772354, 0.06884057971014494, 0.0...
# 2       [0.5, 0.07854406130268199, 0.06122448979591838...
# 3       [0.04263565891472874, 0.05128205128205129, 0.0...
# 4       [0.0, 0.0, 0.4444444444444444, 0.0809523809523...
# ...                                                   ...
# 264242  [0.032863849765258225, 0.15384615384615388, 0....
# 264243  [0.0, 0.5, 0.19444444444444434, 0.100775193798...
# 264244  [0.11827956989247314, 0.10451977401129942, 0.1...
# 264245  [0.09090909090909068, 0.08333333333333333, 0.0...
# 264246  [0.09523809523809525, 0.03763440860215056, 0.1...
#
#                                                         S  \
# 0       [0.07755102040816333, 0.0760233918128654, 0.49...
# 1       [0.2546583850931677, 0.3432835820895523, 0.483...
# 2       [1.0, 0.5337423312883435, 0.6666666666666666, ...
# 3       [0.20975609756097569, 0.2565789473684211, 0.36...
# 4       [0.0, 0.0, 0.0117647058823529, 0.4458598726114...
# ...                                                   ...
# 264242  [0.4226190476190476, 0.24375000000000002, 0.21...
# 264243  [0.0, 0.0039215686274509665, 0.074688796680497...
# 264244  [0.17032967032967034, 0.33714285714285713, 0.3...
# 264245  [0.04435483870967738, 0.0573770491803279, 0.13...
# 264246  [0.24852071005917156, 0.543859649122807, 0.177...
#
#                                                         B
# 0       [0.9607843137254902, 0.6705882352941176, 0.780...
# 1       [0.6313725490196078, 0.5254901960784314, 0.486...
# 2       [0.00784313725490196, 0.6392156862745098, 0.57...
# 3       [0.803921568627451, 0.596078431372549, 0.31372...
# 4       [1.0, 0.9921568627450981, 1.0, 0.6156862745098...
# ...                                                   ...
# 264242  [0.6588235294117647, 0.6274509803921569, 0.215...
# 264243  [1.0, 1.0, 0.9450980392156862, 0.7529411764705...
# 264244  [0.7137254901960784, 0.6862745098039216, 0.654...
# 264245  [0.9725490196078431, 0.9568627450980393, 0.945...
# 264246  [0.6627450980392157, 0.2235294117647059, 0.176...
#
# [264247 rows x 11 columns]

# %%
df.to_csv("omniart-paintings-filtered-clean-hsb.csv", index=False)
