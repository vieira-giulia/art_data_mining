# %%
import pandas as pd
# Mining: 
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules

# %%
df = pd.read_csv("../01_artwork_clustering/omniart-post-artwork-clustering.csv")

# %%
artwork_clusters = pd.read_csv("../01_artwork_clustering/artwork-centroids.csv")

# %%
total_transactions = len(df)
total_transactions
# Out:
# 264218

# %%
min_support = 0.001 # 0.1% -> 0.001*264218 = 264 transactions

# %%
def get_freq_itemset(df, dims, min_support):
    mining_df = df.copy()
    mining_df["cluster"] = "cluster_" + mining_df["cluster"].astype(str)
    for dim in dims:
        mining_df[f"{dim}"] = f"{dim}_" + mining_df[f"{dim}"].astype(str)

    # One-Hot Encode
    df_encoded = pd.get_dummies(mining_df, prefix="", prefix_sep="")
    df_encoded = df_encoded.astype(bool)
    
    # Frequent Itemsets with FP-Growth
    freq_itemsets = fpgrowth(df_encoded, min_support=min_support, use_colnames=True)

    return freq_itemsets

# %%
min_lift = 1.1 # 10% more likely to be related

# %%
def get_association_rules(freq_itemsets, min_threshold, metric="lift"):
    rules = association_rules(freq_itemsets, metric=metric, min_threshold=min_threshold)
    return rules.sort_values(by="lift", ascending=False)

# %% [raw]
# Antecedent: The item(s) on the left-hand side (LHS) of the rule:
#       If these items are present...
#
# Consequent: The item(s) on the right-hand side (RHS) of the rule:
#       ...then these items are likely to also be present.
#
#
# Antecedent support:  Probability that the antecedent occurs in a transaction
#       antecedent support = transactions with antecedent / total transactions
#
# Consequent support: Probability that the consequent occurs in a transaction
#       consequent support = transactions with consequent / total transactions
#
# Support: Probability that **both** antecedent and consequent occur together
#       support = P(A intersection B)
#
#
# Confidence: How often the rule is correct
#       confidence = support / antecedent support = P(B|A)
#           Given A, how likely is B?
#
#
# Lift: How much more likely B is, given A, compared to if A and B were independent:
#       lift = confidence / consequent support  = P(A intersection B) / P(A) * P(B)
#         Lift > 1 → positive association
#         Lift = 1 → independent
#         Lift < 1 → negative association
#
#
# Representativity: Measures how representative the rule is of the cluster or group of items; varies by implementation.
#         representativity = support / cluster support or size
#         Helps in clustering-based rule mining.
#
#
# Leverage: Difference between observed co-occurrence and what would be expected if A and B were independent:
#         leverage = P(A intersection B) - P(A) * P(B)
#           Values near 0 suggest independence.
#
#
# Conviction: Measures the degree of implication (how strongly A implies B):
#         conviction = (1 - P(B)) / (1 - confidence) =  (1 - consequent support) / (1 - confidence)
#           Higher conviction implies stronger implication.
#
#
# Zhangs metric: Measures rule interest accounting for imbalance in frequency:
#         Zhang's metric = (P(A intersection B) - P(A)) * P(B)) /
#                   max(P(A intersection B) * (1 - P(A)), P(A) * (P(B) - P(A intersection B)))
#           Range: $-1, 1$; higher = stronger association.
#
#
# Jaccard: Measures similarity between A and B:
#         Jaccard = P(A intersection B) / (P(A) + P(B) - P(A intersection B))
#
#
# Certainty (Certainty Factor): Indicates how much B is expected given A compared to its baseline probability:
#         certainty = (confidence - consequent support) / (1 - consequent support) , if confidence > consequent support
#                     (confidence} - consequent support) / consequent support      , otherwise
#
#
# Kulczynski (Kulczynski Measure): Averages P(B|A) and P(A|B):
#         Kulczynski = (1/2) * (P(B|A) + P(A|B))

# %% [markdown]
# **1. Decade**

# %%
decade_mining_df = df[["cluster", "decade"]].copy()

# %%
decade_freq_itemset = get_freq_itemset(decade_mining_df, ["decade"], min_support=min_support)

# %%
decade_rules = get_association_rules(decade_freq_itemset, min_threshold=min_lift)

# %%
decade_rules
# Out:
#        antecedents    consequents  antecedent support  consequent support  \
# 99    (cluster_54)  (decade_2000)            0.006090            0.174629
# 98   (decade_2000)   (cluster_54)            0.174629            0.006090
# 58    (cluster_56)  (decade_2000)            0.007305            0.174629
# 59   (decade_2000)   (cluster_56)            0.174629            0.007305
# 5    (decade_2000)   (cluster_33)            0.174629            0.004837
# ..             ...            ...                 ...                 ...
# 1    (decade_2000)   (cluster_36)            0.174629            0.011309
# 117  (decade_2000)   (cluster_18)            0.174629            0.008414
# 116   (cluster_18)  (decade_2000)            0.008414            0.174629
# 18   (decade_2010)   (cluster_55)            0.524480            0.010586
# 19    (cluster_55)  (decade_2010)            0.010586            0.524480
#
#       support  confidence      lift  representativity  leverage  conviction  \
# ...

# %% [markdown]
# **2. School**

# %%
school_mining_df = df[["cluster", "school"]]

# %%
school_freq_itemset = get_freq_itemset(school_mining_df, ["school"], min_support=0.0001)

# %%
school_rules = get_association_rules(school_freq_itemset, min_threshold=min_lift)

# %%
school_rules
# Out:
#                antecedents            consequents  antecedent support  \
# 501           (cluster_52)        (school_ India)            0.021301
# 500        (school_ India)           (cluster_52)            0.001991
# 468           (cluster_32)        (school_ Japan)            0.015033
# 469        (school_ Japan)           (cluster_32)            0.003857
# 517           (cluster_59)        (school_ China)            0.016604
# ..                     ...                    ...                 ...
# 68            (cluster_43)      (school_ Unknown)            0.011752
# 324           (cluster_92)       (school_ modern)            0.010771
# 325       (school_ modern)           (cluster_92)            0.696921
# 358            (cluster_3)  (school_ Netherlands)            0.007906
# 359  (school_ Netherlands)            (cluster_3)            0.018193
#
#      consequent support   support  confidence      lift  representativity  \
# ...

# %% [markdown]
# **3. Decades + Schools**

# %%
decade_school_mining_df = df[["cluster", "decade", "school"]]

# %%
decade_school_freq_itemset = get_freq_itemset(decade_school_mining_df, ["decade", "school"], min_support=min_support)

# %%
decade_school_rules = get_association_rules(decade_school_freq_itemset, min_threshold=min_lift)

# %%
decade_school_rules
# Out:
#                        antecedents                    consequents  \
# 659          (school_ Netherlands)                  (decade_1660)
# 658                  (decade_1660)          (school_ Netherlands)
# 253          (school_ Netherlands)                  (decade_1670)
# 252                  (decade_1670)          (school_ Netherlands)
# 472                  (decade_1620)             (school_ Flanders)
# ..                             ...                            ...
# 183              (school_ Unknown)                   (cluster_43)
# 601               (school_ modern)                   (cluster_92)
# 600                   (cluster_92)               (school_ modern)
# 823  (decade_2010, school_ modern)                   (cluster_65)
# 826                   (cluster_65)  (decade_2010, school_ modern)
#
#      antecedent support  consequent support   support  confidence       lift  \
# 659            0.018193            0.004958  0.002263    0.124402  25.091011
# ...
