# %%
import sys
import os
sys.path.append(os.path.abspath("../../../../"))

import numpy as np
import pandas as pd
import utils
# Classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
# Evaluation
from sklearn.metrics.pairwise import cosine_similarity
import plot_automations as plotter

# %%
df = pd.read_csv("../../../../01_color_clustering/non-weighted/omniart-post-color-clustering.csv")

# %%
# Add decade to creation intervals
df["decade"] = (df["creation_year"] // 10 * 10).astype(int)

# %%
color_clusters = pd.read_csv("../../../../01_color_clustering/non-weighted/color_centroids.csv")

# %% [markdown]
# **1. Split dataset: "Unknown" x other"**

# %%
unknown_df = df[df["school"].str.strip().str.lower() == "unknown"]

# %%
known_df = df[~(df["school"].str.strip().str.lower() == "unknown")]

# %% [markdown]
# **1. Features**

# %%
color_names = color_clusters["HEX"].tolist()
color_to_index = {name: i for i, name in enumerate(color_names)}
n_colors = len(color_names)

# %%
known_color_X = np.vstack(known_df.apply(lambda row: utils.artwork_to_vector(row, n_colors, color_to_index), axis=1))

# %%
unknown_color_X = np.vstack(unknown_df.apply(lambda row: utils.artwork_to_vector(row, n_colors, color_to_index), axis=1))

# %%
artist_encoder = LabelEncoder()

# %%
known_artist_X = artist_encoder.fit_transform(known_df["artist_full_name"]).reshape(-1, 1)

# %%
unknown_artist_X = artist_encoder.fit_transform(unknown_df["artist_full_name"]).reshape(-1, 1)

# %%
decade_encoder = LabelEncoder()

# %%
known_decade_X = decade_encoder.fit_transform(known_df["decade"]).reshape(-1, 1)

# %%
unknown_decade_X = decade_encoder.fit_transform(unknown_df["decade"]).reshape(-1, 1)

# %%
known_X = np.hstack([known_color_X, known_artist_X, known_decade_X])

# %%
unknown_X = np.hstack([unknown_color_X, unknown_artist_X, unknown_decade_X])

# %% [markdown]
# **2. Labels: split between known and unknown schools**

# %%
y_unknown = unknown_df["school"].copy()

# %%
y_known = known_df["school"].copy()

# %%
# Encode only known schools
label_encoder = LabelEncoder()
y_known_encoded = label_encoder.fit_transform(y_known)

# %% [markdown]
# **3. Train Random Forest Classifier**

# %%
clf = RandomForestClassifier(n_estimators=200, max_depth=20, random_state=42)
clf.fit(known_X, y_known_encoded)
# Out:
# RandomForestClassifier(max_depth=20, n_estimators=200, random_state=42)

# %% [markdown]
# **4. Predict school for "unknown" rows**

# %%
probas = clf.predict_proba(unknown_X)
predicted_indices = np.argmax(probas, axis=1)
predicted_schools = label_encoder.inverse_transform(predicted_indices)
confidences = np.max(probas, axis=1)

# %%
unknown_df.copy()
unknown_df.loc[:, "predicted_school"] = predicted_schools
unknown_df.loc[:, "confidence"] = confidences

# %% [markdown]
# **5. Prediction color similarity**

# %%
features_known = known_color_X
labels_known = y_known_encoded
similarities = []

# %%
for x_u, pred_idx in zip(unknown_color_X, predicted_indices):
    class_samples = features_known[labels_known == pred_idx]
    class_mean = class_samples.mean(axis=0)
    sim = cosine_similarity([x_u], [class_mean])[0, 0]
    similarities.append(sim)

# %%
unknown_df.loc[:, "color_similarity"] = similarities

# %%
unknown_df.sort_values(by="confidence", ascending=False, inplace=True)

# %%
unknown_df
# Out:
#                                              artwork_name    artist_full_name  \
# 10706                                    Geniuses of arts    françois boucher
# 128158                                    Femme et enfant      francis gruber
# 102247             Chrysanthemums by a stream, with rocks         ito jakuchu
# 76533                                              Le cri          ivan tovar
# 16401   St. Bonaventura Receiving the Banner of St. Se...  francesco solimena
# ...                                                   ...                 ...
# 163387                    St. Peter Enthroned with Saints  cima da conegliano
# 142602                       St. Jerome in the Wilderness  cima da conegliano
# 242826                                  Madonna and Child  cima da conegliano
# 111507                             The Healing of Anianus  cima da conegliano
# 64080                        The Coronation of the Virgin  cima da conegliano
#
#         creation_year  century    school  \
# 10706          1761.0     18.0   Unknown
# 128158         1939.0     20.0   Unknown
# 102247         1760.0     18.0   Unknown
# 76533          1974.0     20.0   Unknown
# 16401          1710.0     18.0   Unknown
# ...               ...      ...       ...
# 163387         1490.0     15.0   Unknown
# 142602         1495.0     15.0   Unknown
# 242826         1497.0     15.0   Unknown
# 111507         1498.0     15.0   Unknown
# 64080          1490.0     15.0   Unknown
#
#                                             palette_count  \
# 10706   [3612, 7910, 3806, 4778, 7197, 5542, 6642, 496...
# 128158  [5609, 6553, 6408, 6379, 4597, 4588, 7784, 332...
# 102247  [3872, 6383, 5869, 4946, 6883, 8231, 2720, 475...
# 76533   [4800, 4418, 1299, 2146, 5818, 7510, 7616, 408...
# 16401   [3740, 4509, 5649, 7872, 4410, 4234, 3882, 499...
# ...                                                   ...
# 163387  [3775, 4794, 4429, 5925, 6767, 6471, 4849, 496...
# 142602  [4184, 5718, 6706, 4401, 4938, 4904, 7244, 520...
# 242826  [6147, 5574, 5199, 4591, 4096, 3827, 8436, 418...
# 111507  [3906, 5127, 4914, 5348, 7094, 4698, 6160, 494...
# 64080   [4476, 5948, 4711, 5653, 5602, 7679, 8306, 330...
#
#                                             cluster_names  \
# 10706   ['pale-rose', 'light-mauve', 'brownish', 'redd...
# 128158  ['brownish-purple', 'brownish-purple', 'browni...
# 102247  ['blush', 'salmon', 'dark-salmon', 'dull-red',...
# 76533   ['light-grey', 'dull-red', 'dark-rose', 'dark-...
# 16401   ['warm-grey', 'brownish-purple', 'dark', 'dark...
# ...                                                   ...
# 163387  ['pinkish-grey', 'greyish-pink', 'reddish-brow...
# 142602  ['light-grey', 'pinkish-grey', 'pinkish-grey',...
# 242826  ['pinkish', 'dark-rose', 'brick', 'purple-brow...
# 111507  ['blush', 'dark-salmon', 'dark-brown', 'blush'...
# 64080   ['dull-red', 'reddish-brown', 'purplish-brown'...
#
#                                               cluster_hex  decade  \
# 10706   ['#ecc0be', '#be9d9b', '#9e6163', '#a07a79', '...    1760
# 128158  ['#775453', '#775453', '#775453', '#564544', '...    1930
# 102247  ['#eb9c99', '#ed7873', '#cd5853', '#ab3d3c', '...    1760
# 76533   ['#ecdddd', '#c33639', '#ae5856', '#2f2b2b', '...    1970
# 16401   ['#938888', '#884242', '#302121', '#302121', '...    1710
# ...                                                   ...     ...
# 163387  ['#d4b7b9', '#c58f90', '#6b2423', '#564544', '...    1490
# 142602  ['#ecdddd', '#bdb1b0', '#bdb1b0', '#ae5856', '...    1490
# 242826  ['#d17274', '#ae5856', '#a71f22', '#642f2f', '...    1490
# 111507  ['#eb9c99', '#cd5853', '#291313', '#eb9c99', '...    1490
# 64080   ['#ab3d3c', '#6b2423', '#734543', '#642f2f', '...    1490
#
#        predicted_school  confidence  color_similarity
# 10706             Italy        1.00               0.0
# 128158            Italy        1.00               0.0
# 102247            Italy        1.00               0.0
# 76533             Italy        1.00               0.0
# 16401             Italy        1.00               0.0
# ...                 ...         ...               ...
# 163387         Flanders        0.17               0.0
# 142602         Flanders        0.17               0.0
# 242826         Flanders        0.17               0.0
# 111507         Flanders        0.17               0.0
# 64080          Flanders        0.17               0.0
#
# [46860 rows x 12 columns]

# %%
unknown_df.to_csv("unknown_school_predictions.csv", index=False)

# %% [markdown]
# **6. Evaluate**

# %%
unknown_summary = unknown_df.groupby("predicted_school").agg(
    count=("predicted_school", "count"),
    avg_confidence=("confidence", "mean"),
    avg_similarity=("color_similarity", "mean")
).sort_values(by="count", ascending=False)

# %%
unknown_summary
# Out:
#                   count  avg_confidence  avg_similarity
# predicted_school
#  Italy            26245        0.758753             0.0
#  Flanders          8430        0.610391             0.0
#  Netherlands       3368        0.490929             0.0
#  Spain             2679        0.574218             0.0
#  Germany           2658        0.656421             0.0
#  England           1762        0.333598             0.0
#  Austria            684        0.415731             0.0
#  Japan              321        0.338287             0.0
#  Greece             314        0.590872             0.0
#  France             158        0.644960             0.0
#  Egypt              136        0.331029             0.0
#  Russia              66        0.485522             0.0
#  Portugal            30        0.509621             0.0
#  Korea                9        0.591649             0.0

# %% [markdown]
# **7. Features importance**

# %%
importances = clf.feature_importances_

# %%
color_feature_names = color_names
artist_feature_name = ["artist"]
decade_feature_name = ["decade"]

feature_names = color_feature_names + artist_feature_name + decade_feature_name

# %%
importance_df = pd.DataFrame({
    "feature": feature_names,
    "importance": importances
}).sort_values(by="importance", ascending=False)

# %%
importance_df
# Out:
#       feature  importance
# 1001   decade    0.683752
# 1000   artist    0.316248
# 672   #c1afbe    0.000000
# 659   #b39341    0.000000
# 660   #ed5714    0.000000
# ...       ...         ...
# 339   #dac175    0.000000
# 340   #9aabbc    0.000000
# 341   #52697d    0.000000
# 342   #8cb99d    0.000000
# 501   #1e2748    0.000000
#
# [1002 rows x 2 columns]

# %%
importance_df.to_csv("unkown_school_feature_importance.csv", index=False)
