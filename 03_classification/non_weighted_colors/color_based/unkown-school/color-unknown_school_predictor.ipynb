# %%
import sys
import os
sys.path.append(os.path.abspath("../../../../"))

import numpy as np
import pandas as pd
import utils
# Classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
# Evaluation
from sklearn.metrics.pairwise import cosine_similarity
import plot_automations as plotter

# %%
df = pd.read_csv("../../../../01_color_clustering/non-weighted/omniart-post-color-clustering.csv")

# %%
# Add decade to creation intervals
df["decade"] = (df["creation_year"] // 10 * 10).astype(int)

# %%
color_clusters = pd.read_csv("../../../../01_color_clustering/non-weighted/color_centroids.csv")

# %% [markdown]
# **1. Split dataset: "Unknown" x other"**

# %%
unknown_df = df[df["school"].str.strip().str.lower() == "unknown"]

# %%
known_df = df[~(df["school"].str.strip().str.lower() == "unknown")]

# %% [markdown]
# **1. Features**

# %%
color_names = color_clusters["HEX"].tolist()
color_to_index = {name: i for i, name in enumerate(color_names)}
n_colors = len(color_names)

# %%
known_color_X = np.vstack(known_df.apply(lambda row: utils.artwork_to_vector(row, n_colors, color_to_index), axis=1))

# %%
known_X = known_color_X

# %%
unknown_color_X = np.vstack(unknown_df.apply(lambda row: utils.artwork_to_vector(row, n_colors, color_to_index), axis=1))

# %%
unknown_X = unknown_color_X

# %% [markdown]
# **2. Labels: split between known and unknown schools**

# %%
y_unknown = unknown_df["school"].copy()

# %%
y_known = known_df["school"].copy()

# %%
# Encode only known schools
label_encoder = LabelEncoder()
y_known_encoded = label_encoder.fit_transform(y_known)

# %% [markdown]
# **3. Train Random Forest Classifier**

# %%
clf = RandomForestClassifier(n_estimators=200, max_depth=20, random_state=42)
clf.fit(known_X, y_known_encoded)
# Out:
# RandomForestClassifier(max_depth=20, n_estimators=200, random_state=42)

# %% [markdown]
# **4. Predict school for "unknown" rows**

# %%
probas = clf.predict_proba(unknown_X)
predicted_indices = np.argmax(probas, axis=1)
predicted_schools = label_encoder.inverse_transform(predicted_indices)
confidences = np.max(probas, axis=1)

# %%
unknown_df = unknown_df.copy()
unknown_df.loc[:, "predicted_school"] = predicted_schools
unknown_df.loc[:, "confidence"] = confidences

# %%
unknown_df.sort_values(by="confidence", ascending=False, inplace=True)

# %%
unknown_df
# Out:
#                                              artwork_name  \
# 138                            Officers Playing Tric Trac
# 176789  Distribution of Herring and White Bread During...
# 176791         The Landing of Richard II at Milford Haven
# 176792  The Gallant Charge of the Kentucky Cavalry Und...
# 176793  Nikita Pustosviat. Dispute on the Confession o...
# ...                                                   ...
# 88857                                       Sitting Woman
# 88858                                  Naked Man with Rat
# 88859                        Gabriele on the bamboo bed 2
# 88860                      A Vase of Flowers with a Watch
# 264225             Madonna and Child enthroned with donor
#
#                 artist_full_name  creation_year  century    school  \
# 138     willem cornelisz duyster         1650.0     17.0   Unknown
# 176789             otto van veen         1590.0     16.0   Unknown
# 176791          william hamilton         1800.0     19.0   Unknown
# 176792          currier and ives         1847.0     19.0   Unknown
# 176793              vasily perov         1881.0     19.0   Unknown
# ...                          ...            ...      ...       ...
# 88857       vytautas kairiukstis         1930.0     20.0   Unknown
# 88858               lucian freud         1977.0     20.0   Unknown
# 88859            gazmend freitag         2008.0     21.0   Unknown
# 88860           willem van aelst         1650.0     17.0   Unknown
# 264225            carlo crivelli         1470.0     15.0   Unknown
#
#                                             palette_count  \
# 138     [3907, 4482, 4423, 3080, 7328, 4675, 7989, 661...
# 176789  [4016, 5233, 4515, 5618, 4312, 5514, 6439, 596...
# 176791  [4246, 5623, 5923, 5343, 7971, 3539, 6672, 358...
# 176792  [5080, 5937, 8049, 8172, 3905, 3948, 3699, 485...
# 176793  [3671, 5084, 6741, 4797, 5483, 5677, 4176, 581...
# ...                                                   ...
# 88857   [2151, 4881, 9849, 5077, 4076, 2604, 2920, 734...
# 88858   [5444, 6455, 4733, 6279, 4652, 6709, 4069, 503...
# 88859   [8031, 3325, 4571, 4563, 7403, 4998, 2966, 555...
# 88860   [1332, 11718, 11523, 3689, 5097, 3671, 3983, 4...
# 264225  [3976, 4147, 4308, 4749, 3963, 7974, 7985, 702...
#
#                                               cluster_hex  decade  \
# 138     ['#ae5856', '#884242', '#642f2f', '#481819', '...    1650
# 176789  ['#d4b7b9', '#a07a79', '#8b2c2b', '#6b2423', '...    1590
# 176791  ['#91211b', '#884242', '#775453', '#5d1217', '...    1800
# 176792  ['#ecdddd', '#bdb1b0', '#564544', '#481819', '...    1840
# 176793  ['#be9d9b', '#9e6163', '#734543', '#642f2f', '...    1880
# ...                                                   ...     ...
# 88857   ['#eb9c99', '#cd5853', '#be9d9b', '#c33639', '...    1930
# 88858   ['#ecc0be', '#eb9c99', '#d17274', '#ae5856', '...    1970
# 88859   ['#938888', '#938888', '#938888', '#938888', '...    2000
# 88860   ['#291313', '#302121', '#302121', '#bdb1b0', '...    1650
# 264225  ['#eb9c99', '#ba7a75', '#a71f22', '#91211b', '...    1470
#
#        predicted_school  confidence
# 138              modern    0.847212
# 176789           modern    0.847212
# 176791           modern    0.847212
# 176792           modern    0.847212
# 176793           modern    0.847212
# ...                 ...         ...
# 88857            modern    0.847212
# 88858            modern    0.847212
# 88859            modern    0.847212
# 88860            modern    0.847212
# 264225           modern    0.847212
#
# [46860 rows x 10 columns]

# %%
unknown_df.to_csv("color-unknown_school_predictions.csv", index=False)

# %% [markdown]
# **6. Evaluate**

# %%
unknown_summary = unknown_df.groupby("predicted_school").agg(
    count=("predicted_school", "count"),
    avg_confidence=("confidence", "mean"),
).sort_values(by="count", ascending=False)

# %%
unknown_summary
# Out:
#                   count  avg_confidence
# predicted_school
#  modern           46860        0.847212

# %% [markdown]
# **7. Features importance**

# %%
importances = clf.feature_importances_

# %%
color_feature_names = color_names

feature_names = color_feature_names

# %%
importance_df = pd.DataFrame({
    "feature": feature_names,
    "importance": importances
}).sort_values(by="importance", ascending=False)

# %%
importance_df
# Out:
#      feature  importance
# 0    #e73041         0.0
# 671  #75b598         0.0
# 658  #989678         0.0
# 659  #b39341         0.0
# 660  #ed5714         0.0
# ..       ...         ...
# 338  #7b9d60         0.0
# 339  #dac175         0.0
# 340  #9aabbc         0.0
# 341  #52697d         0.0
# 999  #d19615         0.0
#
# [1000 rows x 2 columns]

# %%
importance_df.to_csv("color-unkown-school_feature_importance.csv", index=False)
